# %%
import pandas as pd

# %%
df = pd.read_csv('data/netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df = df.drop_duplicates()  #დუბლირებულ მონაცემებს შლის
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# import pandas as pd
# df = pd.read_csv('data/netflix_titles.csv')
df[["Month", "Day", "Year"]] = df["date_added"].str.split(',',2, expand=True)
df
 #ვცდილობდი თარიღის სვეტი გამეყო 3 ნაწილად და ახალი სვეტები დამემატებინა მაგრამ ერორზე გადის
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 # import pandas as pd
#       2 # df = pd.read_csv('data/netflix_titles.csv')
# ----> 3 df[["Month", "Day", "Year"]] = df["date_added"].str.split(',',2, expand=True)
#       4 df
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# --> 129 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
import pandas as pd
df = pd.read_csv('data/netflix_titles.csv')
df.fillna('...').head(20)
#ცარიელი მნიშვნელობების ადგილას სადაც ეწერა NaN ახლა ცარიელ მნიშვნელობებს ავსებს წერტილებით
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %%
#მეორე ამოცანა
import pandas as pd
df = pd.read_csv('data/Earthquakes_database.csv')
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1/2/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1/4/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1/5/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1/8/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1/9/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df['Magnitude'].max()

# %%
df['Magnitude'].min()

# %%
# df['Magnitude_categories'] = pd.cut(df['Magnitude'], 
#        bins=[int(df['Magnitude'].min())-1, 4, 7, int(df['Magnitude'].max())+1],
#        labels=['low', 'medium', 'high'])

cut_categories = ['low', 'medium', 'high']
cut_bins = [0, 3, 6, 10]
df['magnitude_categories'] = pd.cut(df['Magnitude'], bins=cut_bins, labels=cut_categories)
df
#cut ფუნქციით Earthquakes_database.csv ბაზიდან Magnitude-ის სვეტის მიხედვით მონაცემები იყოფა სამ კატეკორიად, დაბალ, საშუალო და მაღალ მაგნიტუდად

# %%
#მესამე ამოცანა
import numpy as np
import pandas as pd
df = pd.read_csv("data/netflix_titles.csv")
df

# %%
df['title'].explode()

# %%
df.assign(Title_new=df['title'].str.split(" ")).explode("title")

# %%
#pivot table

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
column_names = ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 
                'release_year', 'rating', 'duration', 'listed_in', 'description' , 'Title_new']
Netflix  = pd.read_csv("data/netflix_titles.csv", names = column_names)

print(Netflix.shape)
Netflix.head(10)
# Out:
# (8808, 13)
#    show_id     type                             title  \
# 0  show_id     type                             title
# 1       s1    Movie              Dick Johnson Is Dead
# 2       s2  TV Show                     Blood & Water
# 3       s3  TV Show                         Ganglands
# 4       s4  TV Show             Jailbirds New Orleans
# 5       s5  TV Show                      Kota Factory
# 6       s6  TV Show                     Midnight Mass
# 7       s7    Movie  My Little Pony: A New Generation
# 8       s8    Movie                           Sankofa
# 9       s9  TV Show     The Great British Baking Show
#
#                         director  \
# 0                       director
# 1                Kirsten Johnson
# 2                            NaN
# 3                Julien Leclercq
# 4                            NaN
# 5                            NaN
# 6                  Mike Flanagan
# 7  Robert Cullen, José Luis Ucha
# 8                   Haile Gerima
# ...

# %%
Netflix.info()

# %%
# Netflix.pivot_table(index='rating', columns='date_added',  aggfunc='sum')
# pt = Netflix.pivot_table(index='rating', columns='date_added', values='label_50', aggfunc=['sum'])

# print(pt)
# pt.plot(kind ='bar', figsize=(15,5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 Netflix.pivot_table(index='rating', columns='date_added',  aggfunc='sum')
# ----> 2 pt = Netflix.pivot_table(index='rating', columns='date_added', values='label_50', aggfunc=['sum'])
#       3 # pt = adult.pivot_table(index = 'occupation', columns ='sex', values = 'label_50', aggfunc=['sum'])
#       4 print(pt)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:8579, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8562 @Substitution("")
#    8563 @Appender(_shared_docs["pivot_table"])
#    8564 def pivot_table(
#    (...)
#    8575     sort: bool = True,
#    8576 ) -> DataFrame:
#    8577     from pandas.core.reshape.pivot import pivot_table
# -> 8579     return pivot_table(
# ...

# %%
#მეოთხე ამოცანა
import pandas as pd
df = pd.read_csv('data/Earthquakes_database.csv')
import matplotlib.pyplot as plt
import numpy as np

magnitude = df['Magnitude']
plt.boxplot(magnitude)
plt.show()

# %%
#Line plots
magnitude = df['Magnitude']
depth = df['Depth']
plt.plot(magnitude, depth, 'r--', lw=1)

# %%
#histogram
magnitudedate = df['Magnitude']
plt.hist(magnitudedate, bins=10)
plt.xticks(df['Date'].head(10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\axis.py:1732, in Axis.convert_units(self, x)
#    1731 try:
# -> 1732     ret = self.converter.convert(x, self.units, self)
#    1733 except Exception as e:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# ...

# %%
#მეხუთე ამოცანა
df.head()
df.shape
# Out:
# (23412, 21)

# %%
df.loc[0, 'Date']
# Out:
# '1/2/1965'

# %%
df['Date'].min()
# Out:
# '1/1/1967'

# %%
df['Date'].max()
# Out:
# '9/9/2016'

# %%
df['Date'].max() - df['Date'].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df['Date'].max() - df['Date'].min()
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
df.loc['2016']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df.loc['2016']
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
# ...
